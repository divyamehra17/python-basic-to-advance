# %%
# list- square bracket and mutable
#syntax
# indexing
# slicing operator
# step size
# arthimetic operation

# %%
a=[345,45.6,True,45+6j,"dib"]

# %%
type(a)
# Out:
# list

# %%
#indexing

a[1]
# Out:
# 45.6

# %%
a[0]
# Out:
# 345

# %%
a[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16296/3418884185.py in <module>
# ----> 1 a[100]
#
# IndexError: list index out of range

# %%
a[4]
# Out:
# 'dib'

# %%
a[4][0]
# Out:
# 'd'

# %%
a[3][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16296/711839515.py in <module>
# ----> 1 a[3][1]
#
# TypeError: 'complex' object is not subscriptable

# %%
# slicing operator
a[0:3]
# Out:
# [345, 45.6, True]

# %%
a[1:2]
# Out:
# [45.6]

# %%
a[0:100]
# Out:
# [345, 45.6, True, (45+6j), 'dib']

# %%
# step size
a[1:3:1]
# Out:
# [45.6, True]

# %%
a[1:3:-1]
# Out:
# []

# %%
a[3:1:1]
# Out:
# []

# %%
a[3:1:-1]
# Out:
# [(45+6j), True]

# %%
a[-1:3:1]
# Out:
# []

# %%
a[-1:3:-1]
# Out:
# ['dib']

# %%
a[1:-3:1]
# Out:
# [45.6]

# %%
a[1:-3:-1]
# Out:
# []

# %%
a[3:1:1]
# Out:
# []

# %%
a[3:1:-1]
# Out:
# [(45+6j), True]

# %%
a[-3:1:1]
# Out:
# []

# %%
a[-3:1:-1]
# Out:
# [True]

# %%
a[3:-1:1]
# Out:
# [(45+6j)]

# %%
a[3:-1:-1]
# Out:
# []

# %%
# Arithmetic operator
a
# Out:
# [345, 45.6, True, (45+6j), 'dib']

# %%
b=[567,234.084,False,(56+5j),"djsdja"]

# %%
a+b
# Out:
# [345, 45.6, True, (45+6j), 'dib', 567, 234.084, False, (56+5j), 'djsdja']

# %%
a-b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16296/3931802818.py in <module>
# ----> 1 a-b
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
a*4
# Out:
# [345,
#  45.6,
#  True,
#  (45+6j),
#  'dib',
#  345,
#  45.6,
#  True,
#  (45+6j),
#  'dib',
#  345,
#  45.6,
#  True,
#  (45+6j),
#  'dib',
#  345,
#  45.6,
#  True,
#  (45+6j),
#  'dib']

# %%
a\4
# Out:
#   File "C:\Users\divya\AppData\Local\Temp/ipykernel_16296/2694071735.py", line 1
#     a\4
#       ^
# SyntaxError: unexpected character after line continuation character

# %%
# Inbuilt function
print('a:',a)
print('b:',b)
# Out:
# a: [345, 45.6, True, (45+6j), 'dib', 'dkjak']
# b: [567, 234.084, False, (56+5j), 'djsdja']

# %%
a.append("dkjak")

# %%
b.clear()

# %%
b
# Out:
# []

# %%
a.copy()
# Out:
# [345, 45.6, True, (45+6j), 'dib', 'dkjak']

# %%
a.count('dib')
# Out:
# 1

# %%
a.extend([2,3,4,5])

# %%
a
# Out:
# [345, 45.6, True, (45+6j), 'dib', 'dkjak', 2, 3, 4, 5]

# %%
a.append([2,3,4,5])

# %%
a
# Out:
# [345, 45.6, True, (45+6j), 'dib', 'dkjak', 2, 3, 4, 5, [2, 3, 4, 5]]

# %%
a.index(345)
# Out:
# 0

# %%
a.insert(3,"fkhd")
a
# Out:
# [345,
#  45.6,
#  True,
#  'fkhd',
#  'fkhd',
#  (45+6j),
#  'dib',
#  'dkjak',
#  2,
#  3,
#  4,
#  5,
#  [2, 3, 4, 5]]

# %%
a.pop(3)
a
# Out:
# [345, 45.6, True, (45+6j), 'dib', 'dkjak', 2, 3, 4, 5, [2, 3, 4, 5]]

# %%
a.remove(5)
a
# Out:
# [345, 45.6, True, (45+6j), 'dib', 'dkjak', 2, 3, 4, [2, 3, 4, 5]]

# %%
a.reverse()
a
# Out:
# [[2, 3, 4, 5], 4, 3, 2, 'dkjak', 'dib', (45+6j), True, 45.6, 345]

# %%
c=[2,45,76,8,87,9,3,4]
c
# Out:
# [2, 45, 76, 8, 87, 9, 3, 4]

# %%
c.sort()
c
# Out:
# [2, 3, 4, 8, 9, 45, 76, 87]

# %%
a
# Out:
# [[2, 3, 4, 5], 4, 3, 2, 'dkjak', 'dib', (45+6j), True, 45.6, 345]

# %%
#replace
a[2]=789
a
# Out:
# [[2, 3, 4, 5], 4, 789, 2, 'dkjak', 'dib', (45+6j), True, 45.6, 345]

# %%
a[4]
# Out:
# 'dkjak'

# %%
a[4][0]
# Out:
# 'd'

# %%
a[4][0]='r'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16296/1927504844.py in <module>
# ----> 1 a[4][0]='r'
#
# TypeError: 'str' object does not support item assignment

# %%
a[6]
# Out:
# (45+6j)

# %%
a[6][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16296/2445011641.py in <module>
# ----> 1 a[6][0]
#
# TypeError: 'complex' object is not subscriptable

# %%
a
# Out:
# [[2, 3, 4, 5], 4, 789, 2, 'dkjak', 'dib', (45+6j), True, 45.6, 345]

# %%
a[7]
# Out:
# True

# %%
a[7][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16296/2991156538.py in <module>
# ----> 1 a[7][0]
#
# TypeError: 'bool' object is not subscriptable

# %%
a[]
