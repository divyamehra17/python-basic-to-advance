# %%
#Lecture -1
#data types-int,float,boolean,complex,string
#print,length,type
#typecasting
#taking input from the user

# %%
#data types-int,float,boolean,complex,string
#integer(int)
#float(float)
#boolean(bool)
#complex(complex)
#string(str)

# %%
#integer(int)-
a=4
a
# Out:
# 4

# %%
#float(float)
b=45.6
b
# Out:
# 45.6

# %%
#boolean(bool)
c=True
c
# Out:
# True

# %%
#complex(complex)
d=4+5j
d
# Out:
# (4+5j)

# %%
#string(str)
e="divya"
e
# Out:
# 'divya'

# %%
#print-display on the screen

# %%
#integer(int)-
a=4
print(a)
# Out:
# 4

# %%
#float(float)
b=45.6
print(b)
# Out:
# 45.6

# %%
#boolean(bool)
c=True
print(c)
# Out:
# True

# %%
#complex(complex)
d=4+5j
print(d)
# Out:
# (4+5j)

# %%
#string(str)
e="divya"
print(e)
# Out:
# divya

# %%
#len-length

# %%
#integer(int)-
a=4
len(a)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-13-f19be30452fe> in <module>()
#       1 #integer(int)-
#       2 a=4
# ----> 3 len(a)
#
# TypeError: object of type 'int' has no len()

# %%
#float(float)
b=45.6
len(b)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-14-1963fee2e1d8> in <module>()
#       1 #float(float)
#       2 b=45.6
# ----> 3 len(b)
#
# TypeError: object of type 'float' has no len()

# %%
#boolean(bool)
c=True
len(c)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-15-34450e7727f0> in <module>()
#       1 #boolean(bool)
#       2 c=True
# ----> 3 len(c)
#
# TypeError: object of type 'bool' has no len()

# %%
#complex(complex)
d=4+5j
len(d)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-16-8323047899ef> in <module>()
#       1 #complex(complex)
#       2 d=4+5j
# ----> 3 len(d)
#
# TypeError: object of type 'complex' has no len()

# %%
#string(str)
e="divya"
len(e)
# Out:
# 5

# %%
#types- type of the variable

# %%
#integer(int)-
a=4
type(a)
# Out:
# int

# %%
#float(float)
b=45.6
type(b)
# Out:
# float

# %%
#boolean(bool)
c=True
type(c)
# Out:
# bool

# %%
#complex(complex)
d=4+5j
type(d)
# Out:
# complex

# %%
#string(str)
e="divya"
type(e)
# Out:
# str

# %%
# typecasting----

# %%
#integer(int) into float(float)
b=45.6
a=4
float(a)+b
# Out:
# 49.6

# %%
#integer(int) into boolean(bool)
c=True
a=4
bool(a)+c
# Out:
# 2

# %%
#integer(int) into complex(complex)
d=4+5j
a=4
complex(a)+d
# Out:
# (8+5j)

# %%
#integer(int) into string(str)
a=4
e="divya"
str(a)+e
# Out:
# '4divya'

# %%
#integer(int) into integer(int)
a=4
a=4
int(a)+a
# Out:
# 8

# %%
#float(float) into integer(int)
b=45.6
a=4
int(b)+a
# Out:
# 49

# %%
#float(float) into boolean(bool)
b=45.6
c=True
bool(b)+c
# Out:
# 2

# %%
#float(float) into complex(complex)
b=45.6
d=4+5j
complex(b)+d
# Out:
# (49.6+5j)

# %%
#float(float) into string(str)
b=45.6
e="divya"
str(b)+d
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-33-500b3d3e693d> in <module>()
#       2 b=45.6
#       3 e="divya"
# ----> 4 str(b)+d
#
# TypeError: cannot concatenate 'str' and 'complex' objects

# %%
#float(float) into float(float)
b=45.6
b=45.6
float(b)+b
# Out:
# 91.2

# %%
#boolean(bool) into integer(int)
c=True
a=4
int(c)+a
# Out:
# 5

# %%
#boolean(bool) into float(float)
c=True
b=45.6
float(c)+b
# Out:
# 46.6

# %%
#boolean(bool) into complex(complex)
c=True
d=4+5j
complex(c)+d
# Out:
# (5+5j)

# %%
#boolean(bool) into string(str)
c=True
e="divya"
str(c)+e
# Out:
# 'Truedivya'

# %%
#boolean(bool) into boolean(bool)
c=True
c=True
bool(c)+c
# Out:
# 2

# %%
#complex(complex) into integer(int)
d=4+5j
a=4
int(d)+a
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-45-b0352a9f69ca> in <module>()
#       2 d=4+5j
#       3 a=4
# ----> 4 int(d)+a
#
# TypeError: can't convert complex to int

# %%
#complex(complex) into float(float)
d=4+5j
b=45.6
float(d)+b
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-46-7858941ea22d> in <module>()
#       2 d=4+5j
#       3 b=45.6
# ----> 4 float(d)+b
#
# TypeError: can't convert complex to float

# %%
#complex(complex) into boolean(bool)
d=4+5j
c=True
bool(d)+c
# Out:
# 2

# %%
#complex(complex) into  string(str)
d=4+5j
e="divya"
str(d)+e
# Out:
# '(4+5j)divya'

# %%
#complex(complex) into complex(complex)
d=4+5j
d=4+5j
complex(d)+d
# Out:
# (8+10j)

# %%
#string(str) into integer(int)
e="divya"
a=4
int(e)+a
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-50-0eb88b8e1e91> in <module>()
#       2 e="divya"
#       3 a=4
# ----> 4 int(e)+a
#
# ValueError: invalid literal for int() with base 10: 'divya'

# %%
#string(str) into float(float)
e="divya"
b=45.6
float(e)+b
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-51-f1d62cb67a22> in <module>()
#       2 e="divya"
#       3 b=45.6
# ----> 4 float(e)+b
#
# ValueError: could not convert string to float: divya

# %%
#string(str) into complex(complex)
e="divya"
d=4+5j
complex(e)+d
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-52-4f107b70e294> in <module>()
#       2 e="divya"
#       3 d=4+5j
# ----> 4 complex(e)+d
#
# ValueError: complex() arg is a malformed string

# %%
#string(str) into boolean(boolean)
e="divya"
c=True
bool(e)+c
# Out:
# 2

# %%
#string(str) into string(str) 
e="divya"
e="divya"
str(e)+e
# Out:
# 'divyadivya'

# %%
# Taking the input from the user

# %%
input()
# Out:
# True
# True
