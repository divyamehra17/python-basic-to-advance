# %%
#data types
# integer

a=456783

# %%
a.as_integer_ratio()
# Out:
# (456783, 1)

# %%
a.bit_length()
# Out:
# 19

# %%
a.conjugate()
# Out:
# 456783

# %%
a.denominator
# Out:
# 1

# %%
a.from_bytes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13204/2657186374.py in <module>
# ----> 1 a.from_bytes()
#
# TypeError: from_bytes() missing required argument 'bytes' (pos 1)

# %%
a.imag
# Out:
# 0

# %%
a.numerator
# Out:
# 456783

# %%
a.real
# Out:
# 456783

# %%
a.to_bytes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13204/711588480.py in <module>
# ----> 1 a.to_bytes()
#
# TypeError: to_bytes() missing required argument 'length' (pos 1)

# %%
# float - inbuilt function

b=45.678

# %%
b.as_integer_ratio()
# Out:
# (401787937068417, 8796093022208)

# %%
b.conjugate()
# Out:
# 45.678

# %%
b.fromhex()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13204/2548553587.py in <module>
# ----> 1 b.fromhex()
#
# TypeError: float.fromhex() takes exactly one argument (0 given)

# %%
b.hex()
# Out:
# '0x1.6d6c8b4395810p+5'

# %%
b.imag
# Out:
# 0.0

# %%
b.is_integer()
# Out:
# False

# %%
b.real
# Out:
# 45.678

# %%
#boolean
c=True

# %%
c.as_integer_ratio()
# Out:
# (1, 1)

# %%
c.bit_length()
# Out:
# 1

# %%
c.conjugate()
# Out:
# 1

# %%
c.denominator
# Out:
# 1

# %%
c.from_bytes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13204/2874992542.py in <module>
# ----> 1 c.from_bytes()
#
# TypeError: from_bytes() missing required argument 'bytes' (pos 1)

# %%
c.imag
# Out:
# 0

# %%
c.numerator
# Out:
# 1

# %%
c.real
# Out:
# 1

# %%
c.to_bytes
# Out:
# <function bool.to_bytes(length, byteorder, *, signed=False)>

# %%
#complex- no inbuilt function
d=45+6j

# %%
d.conjugate()
# Out:
# (45-6j)

# %%
d.imag
# Out:
# 6.0

# %%
d.real
# Out:
# 45.0

# %%
# string
e = "i am working in a ineuron"

# %%
e.capitalize()
# Out:
# 'I am working in a ineuron'

# %%
e.casefold()
# Out:
# 'i am working in a ineuron'

# %%
e.center(40,"#")
# Out:
# '#######i am working in a ineuron########'

# %%
e.count('w')
# Out:
# 1

# %%
e.encode()
# Out:
# b'i am working in a ineuron'

# %%
e.endswith('s')
# Out:
# False

# %%
e.expandtabs()
# Out:
# 'i am working in a ineuron'

# %%
e.find('a')
# Out:
# 2

# %%
e.format('i')
# Out:
# 'i am working in a ineuron'

# %%
e.format_map('a')
# Out:
# 'i am working in a ineuron'

# %%
e.index('a')
# Out:
# 2

# %%
e.isalnum()
# Out:
# False

# %%
e.isalpha()
# Out:
# False

# %%
e.isascii()
# Out:
# True

# %%
e.isdecimal()
# Out:
# False

# %%
e.isdigit()
# Out:
# False

# %%
e.isidentifier()
# Out:
# False

# %%
e.islower()
# Out:
# True

# %%
e.isnumeric()
# Out:
# False

# %%
e.isprintable()
# Out:
# True

# %%
e.isspace()
# Out:
# False

# %%
e.istitle()
# Out:
# False

# %%
e.isupper()
# Out:
# False

# %%
e.join("ranu")
# Out:
# 'ri am working in a ineuronai am working in a ineuronni am working in a ineuronu'

# %%
e.upper()
# Out:
# 'I AM WORKING IN A INEURON'

# %%
e.translate('hindi')
# Out:
# 'i am working in a ineuron'

# %%
e.title()
# Out:
# 'I Am Working In A Ineuron'

# %%
e.swapcase()
# Out:
# 'I AM WORKING IN A INEURON'

# %%
e.strip()
# Out:
# 'i am working in a ineuron'

# %%
e.startswith('r')
# Out:
# False

# %%
e.split()
# Out:
# ['i', 'am', 'working', 'in', 'a', 'ineuron']
